# %% [markdown]
# # Funções

# %%
#-----------------------------------------------------------------------------------
#  Função que plota circulos de distância em geral
#-----------------------------------------------------------------------------------
def evm_plota_aneis_em_geral(aneis, lon_r, lat_r, color, label):

    """
    Retorna círculos de distância centrado no radar

    Parâmetros de entrada:
                           aneis (lista): tamanho do raio do círculo em km
                           lon_r (float): valor da longitude do centro do círculo em graus
                           lat_r (float): valor da latitude do centro do círculo em graus
                           color (str): cor do raio do círculo
                           label (str): legenda

    Parâmetros de saída:
                         latitude e longitude que delimitam os círculos de distância centrado no radar e plota os círculos

    Exemplo:
             evm_plota_aneis_em_geral([100], -45.97279, -23.600795, 'gray', label='Radar: 100 km')
    """

    import geopy                              # Biblioteca para geocodificação
    from geopy import distance                # Função para calculo de distância
    import numpy as np

    origin = geopy.Point(lat_r, lon_r)

    lons = np.zeros((len(aneis), 361))
    lats = np.zeros((len(aneis), 361))
    for i, dis in enumerate(aneis):
        xpts = []
        ypts = []
        for az in range(361):
            destination = distance.distance(kilometers=dis).destination(origin, az)
            lat2, lon2 = destination.latitude, destination.longitude
            xpts.append(lon2)
            ypts.append(lat2)
        lons[i,:] = xpts[:]
        lats[i,:] = ypts[:]

    for i, anel in enumerate(aneis):
        ax.plot(lons[i,:], lats[i,:], color=color, label= label, lw=0.5)

# %% [markdown]
# # Entendendo o arquivo que será utilizado

# %%
import xarray as xr
dir_input = '/Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI/'
ds = xr.open_dataset(f'{dir_input}cappi_3000m_fcth_20230218_000503.nc')
ds

# %%
print(ds['rainrate_z'].min(), ds['rainrate_z'].max())

# %%
ds['rainrate_z']

# %%
import pyart
ds['rainrate_z'].plot(cmap='pyart_LangRainbow12', vmin=1, vmax=50)

# %% [markdown]
# # Gera netcdf de chuva acumulada

# %%
# %%time
#========================================================================================================================#
#                                              IMPORTAÇÃO DAS BIBLIOTECAS
#========================================================================================================================#
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import pyart
import pandas as pd
import numpy as np
import glob
from datetime import datetime
import xarray as xr
import warnings
warnings.filterwarnings("ignore")

#========================================================================================================================#
#                                                 DIRETÓRIOS
#========================================================================================================================#
dir_input = '/Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI/'
dir_output = '/Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/06_ACUMULADO_PRECIPITACAO/'

#========================================================================================================================#
#                                                 PROCESSAMENTO
#========================================================================================================================#
# datas
datas = ['20230218','20230219']
#datas=datas[0:1]
            
# taxa de conversão de 1h para 5min 
fator = 5./60.

# escolha a estimativa de chuva
estimativa_chuva = 'rainrate_z'
estimativa_chuva = 'rainrate_kdp'
estimativa_chuva = 'rainrate_z_kdp'
estimativa_chuva = 'rainrate_z_zdr_kdp'
estimativa_chuva = 'rainrate_z_zdr_kdp_filtrokdp'

# loop das datas
for data in datas:

    print('data===>>', data)
    
    # inicializa a variável de soma da chuva
    chuva_total = np.zeros([500,500])

    # lista dos arquivos daquela data
    files = sorted(glob.glob(f'{dir_input}cappi_3000m_fcth_{data}*.nc')) # Exemplo: cappi_3000m_fcth_20230218_021502.nc

    # loop dos arquivos daquela data
    for file in files:

        print('PROCESSANDO ===>>', file)

        # leitura do arquivo netcdf
        ds = xr.open_dataset(file)

        # transforma "NaN" para "0.0"
        chuva_atual = ds[estimativa_chuva][:,:]
        chuva_atual = np.where(~np.isnan(chuva_atual), chuva_atual, 0.0)

        # soma total de chuva
        chuva_total = chuva_total + (chuva_atual*fator)

    # Salva arquivo em formato NETCDF
    # define encoding para compactação dos dados
    encoding = {'rain_acumulado_dia': {'zlib': True}}

.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_020502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_021002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_021502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_022002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_022504.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_023003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_023504.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_024003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_024503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_025003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_025503.nc
# ...
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_150503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_151002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_151502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_152003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_152503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_153003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_153503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_154003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_154503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_155003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_155502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_160002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_160502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_161002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_161502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_162004.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_162504.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_163004.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_163504.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_164004.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_164503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_165003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_165503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_170003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_170503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_171003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_171503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_172004.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_172503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_173003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_173503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_174003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_174503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_175003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_175503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_180003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_180502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_181003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_181502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_182004.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_182504.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_183004.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_183504.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_184004.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_184504.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_185003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_185503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_190003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_190503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_191003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_191503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_192003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_192503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_193004.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_193504.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_194003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_194503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_195003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_195503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_200003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_200503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_201003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_201503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_202003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_202502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_203002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_203502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_204002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_204502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_205002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_205502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_210002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_210501.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_211001.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_211501.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_212003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_212503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_213003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_213503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_214003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_214503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_215002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_215502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_220002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_220502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_221002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_221502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_222003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_222503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_223002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_223502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_224002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_224502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_225002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_225502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_230002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_230502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_231002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_231502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_232003.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_232503.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_233002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_233502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_234002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_234502.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_235002.nc
# PROCESSANDO ===>> /Users/enriq/Downloads/PROCESSAMENTO_PYTHON/ARTIGO_LITORAL_NORTE_2023/output/05b_NETCDF_CAPPI\cappi_3000m_fcth_20230219_235502.nc
# CPU times: total: 3.97 s
# Wall time: 5.76 s

# %% [markdown]
# # Plota cappi da chuva acumulada

# %% [markdown]
# ## Testes

# %%
# exemplo do arquivo NETCDF gerado
netcdf = xr.open_dataset('output/06_ACUMULADO_PRECIPITACAO/chuva_acumulada_fcth_20230218_rainrate_z_zdr_kdp_filtrokdp.nc')
netcdf
# Out:
# <xarray.Dataset>
# Dimensions:             (lat: 500, lon: 500)
# Coordinates:
#   * lat                 (lat) float64 -25.83 -25.82 -25.81 ... -21.34 -21.33
#   * lon                 (lon) float64 -48.47 -48.46 -48.45 ... -43.49 -43.48
# Data variables:
#     rain_acumulado_dia  (lat, lon) float64 ...
# Attributes:
#     description:    Constant Altitude Plan Position Indicator (CAPPI) de prec...
#     creation_data:  2025-02-20 19:47:40.385376
#     author:         Enrique V. Mattos
#     email:          enrique@unifei.edu.br

# %%
netcdf['rain_acumulado_dia']
# Out:
# <xarray.DataArray 'rain_acumulado_dia' (lat: 500, lon: 500)>
# [250000 values with dtype=float64]
# Coordinates:
#   * lat      (lat) float64 -25.83 -25.82 -25.81 -25.8 ... -21.35 -21.34 -21.33
#   * lon      (lon) float64 -48.47 -48.46 -48.45 -48.44 ... -43.5 -43.49 -43.48
# Attributes:
#     units:      mm/dia
#     long_name:  Acumulado de Precipitação por Dia

# %%
# plota mapa 
netcdf['rain_acumulado_dia'][:,:].plot(figsize=(9,7), cmap='pyart_NWSRef', vmin=0, vmax=450)

# %% [markdown]
# ## Plota figura

# %%
# importa bibliotecas
import cartopy.crs as ccrs
import matplotlib.pyplot as plt
import proplot as pplt
import xarray as xr
import salem   

# localização do radar
lat_radar, lon_radar = -23.600795, -45.97279

# lista das estimativa de chuva
estimativas_chuva = ['rainrate_z', 
                     'rainrate_kdp', 
                     'rainrate_z_kdp', 
                     'rainrate_z_zdr_kdp', 
                     'rainrate_z_zdr_kdp_filtrokdp']

# soma a chuva dos dois dias 
for estimativa_chuva in estimativas_chuva:

    print(estimativa_chuva)

    # define a variável da chuva total
    chuva_18e19 = np.zeros([500,500])

    # leitura dos arquivos
    chuva_dia18 = xr.open_dataset(f'output/06_ACUMULADO_PRECIPITACAO/chuva_acumulada_fcth_20230218_{estimativa_chuva}.nc')
    chuva_dia19 = xr.open_dataset(f'output/06_ACUMULADO_PRECIPITACAO/chuva_acumulada_fcth_20230219_{estimativa_chuva}.nc')  

    # transforma "NaN" para "0.0"
    chuva_dia18_notnan = chuva_dia18['rain_acumulado_dia'][:,:]
    chuva_dia18_notnan = np.where(~np.isnan(chuva_dia18_notnan), chuva_dia18_notnan, 0.0)

    chuva_dia19_notnan = chuva_dia19['rain_acumulado_dia'][:,:]
    chuva_dia19_notnan = np.where(~np.isnan(chuva_dia19_notnan), chuva_dia19_notnan, 0.0)

    # soma total de chuva
    chuva_18e19 = chuva_dia18_notnan + chuva_dia19_notnan

   # transforma para dataset
    data_vars = {'rain_acumulado_dia_18e19': (('lat', 'lon'), chuva_18e19, {'units': 'mm/dia', 'long_name': 'Acumulado de Precipitação para 18 e 19/fev/2023', '_FillValue': 0})}
    coords = {'lat': chuva_dia18['lat'].values, 'lon': chuva_dia18['lon'].values}
    ds = xr.Dataset(data_vars = data_vars, coords = coords)

    # cria moldura da figura
    fig, ax = pplt.subplots(axheight=5, tight=True, proj='pcarree')

    # exatrai os limites dos dados de CAPPI
    #lonmin, lonmax, latmin, latmax = float(ds['lon'].min()), float(ds['lon'].max()), float(ds['lat'].min()), float(ds['lat'].max())
    lonmin, lonmax, latmin, latmax = -47.2, -44.8, -24.6, -22.6  
    
    # formatação dos eixos
    ax.format(coast=False, borders=False, innerborders=False,
              labels=True,
              latlines=0.5, lonlines=0.5,
              title = f'{estimativa_chuva}',
              latlim=(latmin, latmax),
              lonlim=(lonmin, lonmax),
              small='20px',
              large='15px',
              abc=False)

    # plota mapa
    map1 = ax.contourf(ds['lon'],
                       ds['lat'],
                       ds['rain_acumulado_dia_18e19'][:,:],
                       cmap='pyart_LangRainbow12',
                       levels=pplt.arange(10, 430., 25),
                       vmin=10, vmax=430)
    #pyart_NWSRef
    #pyart_LangRainbow12

    #--------------------------#
    # aneis de distância do radar
    #--------------------------#
    evm_plota_aneis_em_geral([50], lon_radar, lat_radar, 'gray', label='50 km')
    evm_plota_aneis_em_geral([100], lon_radar, lat_radar, 'black', label='100 km')

    # plota o shapefile dos Estados
    estados_brasil = salem.read_shapefile('https://github.com/evmpython/shapefile/raw/refs/heads/main/estados_do_brasil/BR_UF_2019.shp')
    estados_selecionado = estados_brasil.loc[ (estados_brasil['SIGLA_UF'] == 'SP' ) | (estados_brasil['SIGLA_UF'] == 'MG') | (estados_brasil['SIGLA_UF'] == 'RJ')]
    estados_selecionado.plot(edgecolor='gray', facecolor='none', linewidth=0.5, alpha=1, ax=ax)

    #--------------------------#
    #  barra de cor/legenda
    #--------------------------#
    fig.colorbar(map1, loc='r', label='mm/h', ticks=50, ticklabelsize=15, labelsize=15, width=0.20, space=-2.5)

    # adiciona legenda
    ax.legend(loc='lr', ncols=1, frameon=False, prop={'size':7.5}, markerscale=0.4)

    #--------------------------#
    #       salva figura
    #--------------------------#
    fig.save(f'output/06_ACUMULADO_PRECIPITACAO/chuva_acumulada_fcth_{estimativa_chuva}.png', dpi=300)
# Out:
# rainrate_z
# rainrate_kdp
# rainrate_z_kdp
# rainrate_z_zdr_kdp
# rainrate_z_zdr_kdp_filtrokdp
# Figure(nrows=1, ncols=1, refheight=5.0)
# Figure(nrows=1, ncols=1, refheight=5.0)
# Figure(nrows=1, ncols=1, refheight=5.0)
# Figure(nrows=1, ncols=1, refheight=5.0)
# Figure(nrows=1, ncols=1, refheight=5.0)
